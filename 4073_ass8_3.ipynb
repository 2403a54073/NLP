# %%
D1 = "Climate change is one of the most pressing challenges facing humanity in the twenty first century."

D2 = "It refers to long term changes in temperature, precipitation patterns, and other atmospheric conditions on Earth."

D3 = "Although natural factors have influenced the climate throughout history, the current rate of change is largely driven by human activities."

D4 = "The burning of fossil fuels such as coal, oil, and natural gas releases large amounts"

# %%
import collections

# Combine the text from D1, D2, D3, D4
combined_text = f"{D1} {D2} {D3} {D4}"

# Tokenize the combined text into words and convert to lowercase
words = combined_text.lower().split()

# Calculate unigram counts
unigram_counts = collections.Counter(words)

# Print the unigram counts
print("Unigram Counts:")
for word, count in unigram_counts.most_common():
    print(f"{word}: {count}")
#Vocabulary size is length of unigrams
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# Unigram Counts:
# the: 5
# of: 3
# climate: 2
# change: 2
# is: 2
# in: 2
# and: 2
# natural: 2
# one: 1
# most: 1
# pressing: 1
# challenges: 1
# facing: 1
# humanity: 1
# twenty: 1
# first: 1
# century.: 1
# it: 1
# refers: 1
# to: 1
# long: 1
# term: 1
# changes: 1
# temperature,: 1
# precipitation: 1
# patterns,: 1
# other: 1
# atmospheric: 1
# conditions: 1
# on: 1
# earth.: 1
# although: 1
# factors: 1
# have: 1
# influenced: 1
# throughout: 1
# history,: 1
# current: 1
# rate: 1
# largely: 1
# driven: 1
# by: 1
# human: 1
# activities.: 1
# burning: 1
# fossil: 1
# fuels: 1
# such: 1
# as: 1
# coal,: 1
# oil,: 1
# gas: 1
# releases: 1
# large: 1
# amounts: 1
# Vocabulary Size= 55

# %%
import collections


combined_text = f"{D1} {D2} {D3} {D4}"
words = combined_text.lower().split()

# Generate bigrams
bigrams = []
for i in range(len(words) - 1):
    bigrams.append((words[i], words[i+1]))

# Calculate bigram counts
bigram_counts = collections.Counter(bigrams)

# Print the bigram counts
print("\nBigram Counts:")
for bigram, count in bigram_counts.most_common():
    print(f"{bigram[0]} {bigram[1]}: {count}")
# Out:
# Bigram Counts:
# change is: 2
# climate change: 1
# is one: 1
# one of: 1
# of the: 1
# the most: 1
# most pressing: 1
# pressing challenges: 1
# challenges facing: 1
# facing humanity: 1
# humanity in: 1
# in the: 1
# the twenty: 1
# twenty first: 1
# first century.: 1
# century. it: 1
# it refers: 1
# refers to: 1
# to long: 1
# long term: 1
# term changes: 1
# changes in: 1
# in temperature,: 1
# temperature, precipitation: 1
# precipitation patterns,: 1
# patterns, and: 1
# and other: 1
# other atmospheric: 1
# atmospheric conditions: 1
# conditions on: 1
# on earth.: 1
# earth. although: 1
# although natural: 1
# natural factors: 1
# factors have: 1
# have influenced: 1
# influenced the: 1
# the climate: 1
# climate throughout: 1
# throughout history,: 1
# history, the: 1
# the current: 1
# current rate: 1
# rate of: 1
# of change: 1
# is largely: 1
# largely driven: 1
# driven by: 1
# by human: 1
# human activities.: 1
# activities. the: 1
# the burning: 1
# burning of: 1
# of fossil: 1
# fossil fuels: 1
# fuels such: 1
# such as: 1
# as coal,: 1
# coal, oil,: 1
# oil, and: 1
# and natural: 1
# natural gas: 1
# gas releases: 1
# releases large: 1
# large amounts: 1

# %%
import collections


combined_text = f"{D1} {D2} {D3} {D4}"
words = combined_text.lower().split()

# Generate bigrams
Trigrams = []
for i in range(len(words) - 2):
    Trigrams.append((words[i], words[i+1], words[i+2]))

# Calculate bigram counts
Trigrams_counts = collections.Counter(Trigrams)

# Print the bigram counts
print("\nTrigrams Counts:")
for Trigrams, count in Trigrams_counts.most_common():
    print(f"{Trigrams[0]} {Trigrams[1]} {Trigrams[2]}: {count}")
# Out:
# Trigrams Counts:
# climate change is: 1
# change is one: 1
# is one of: 1
# one of the: 1
# of the most: 1
# the most pressing: 1
# most pressing challenges: 1
# pressing challenges facing: 1
# challenges facing humanity: 1
# facing humanity in: 1
# humanity in the: 1
# in the twenty: 1
# the twenty first: 1
# twenty first century.: 1
# first century. it: 1
# century. it refers: 1
# it refers to: 1
# refers to long: 1
# to long term: 1
# long term changes: 1
# term changes in: 1
# changes in temperature,: 1
# in temperature, precipitation: 1
# temperature, precipitation patterns,: 1
# precipitation patterns, and: 1
# patterns, and other: 1
# and other atmospheric: 1
# other atmospheric conditions: 1
# atmospheric conditions on: 1
# conditions on earth.: 1
# on earth. although: 1
# earth. although natural: 1
# although natural factors: 1
# natural factors have: 1
# factors have influenced: 1
# have influenced the: 1
# influenced the climate: 1
# the climate throughout: 1
# climate throughout history,: 1
# throughout history, the: 1
# history, the current: 1
# the current rate: 1
# current rate of: 1
# rate of change: 1
# of change is: 1
# change is largely: 1
# is largely driven: 1
# largely driven by: 1
# driven by human: 1
# by human activities.: 1
# human activities. the: 1
# activities. the burning: 1
# the burning of: 1
# burning of fossil: 1
# of fossil fuels: 1
# fossil fuels such: 1
# fuels such as: 1
# such as coal,: 1
# as coal, oil,: 1
# coal, oil, and: 1
# oil, and natural: 1
# and natural gas: 1
# natural gas releases: 1
# gas releases large: 1
# releases large amounts: 1

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1
    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "Climate change"
next_word1 = predict_next_word_bigram(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "temperature,precipitation"
next_word2 = predict_next_word_bigram(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "Although natural"
next_word3 = predict_next_word_bigram(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of  is is  1.0
# Given sequence: 'Climate change', predicted next word: 'is'
# Given sequence: 'temperature,precipitation', predicted next word: 'No bigram found starting with 'temperature,precipitation'.'
# probability of  factors is  0.5
# probability of  gas is  0.5
# Given sequence: 'Although natural', predicted next word: 'factors'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textAlthough natural
# probability of  factors is  0.5
# probability of  gas is  0.5
# Given sequence: 'Although natural', predicted next word: 'factors'

# %%
def predict_next_word_trigram(word_sequence, Trigrams_counts, bigram_counts):
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count
    # The 'if not potential_next_words:' check should be outside the loop if it applies to all potential next words.
    # Moving it here to prevent it from being checked for every iteration.
    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word
    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "Climate change is "
next_word1 = predict_next_word_trigram(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "long term changes"
next_word2 = predict_next_word_trigram(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  one is  0.5
# probability of  largely is  0.5
# Given sequence: 'Climate change is ', predicted next word: 'one'
# probability of  in is  1.0
# Given sequence: 'long term changes', predicted next word: 'in'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textlong term changes
# probability of  in is  1.0
# Given sequence: 'long term changes', predicted next word: 'in'

# %%
def predict_next_word_bigram_Laplace(word_sequence, bigram_counts, unigram_counts):
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1
    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+1) / (last_word_unigram_count+V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "Climate change"
next_word1 = predict_next_word_bigram_Laplace(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "long term "
next_word2 = predict_next_word_bigram_Laplace(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "largely driven"
next_word3 = predict_next_word_bigram_Laplace(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")
# Out:
# probability of is is  0.05263157894736842
# Given sequence: 'Climate change', predicted next word: 'is'
# probability of changes is  0.03571428571428571
# Given sequence: 'long term ', predicted next word: 'changes'
# probability of by is  0.03571428571428571
# Given sequence: 'largely driven', predicted next word: 'by'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_Laplace(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textnatural gas
# probability of releases is  0.03571428571428571
# Given sequence: 'natural gas', predicted next word: 'releases'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textnatural factors have
# probability of  influenced is  1.0
# Given sequence: 'natural factors have', predicted next word: 'influenced'
