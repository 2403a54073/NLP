# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54073/NLP/blob/main/4073_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install NLTK and spaCy. spaCy requires a model to be downloaded as well.
# !pip install nltk spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 111.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Import the installed libraries
import nltk
import spacy

# Download necessary NLTK data (e.g., for tokenization)
nltk.download('punkt')
nltk.download('punkt_tab') # Added to resolve LookupError

print("NLTK and spaCy are installed and ready!")
# Out:
# NLTK and spaCy are installed and ready!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Example text (replace with your own)
text_data = """Natural language processing (NLP) is a subfield of artificial intelligence, computer science, and computational linguistics. It is concerned with the interactions between computers and human (natural) languages, in particular how to program computers to process and analyze large amounts of natural language data. The goal is to enable computers to understand, interpret, and generate human language in a valuable way."""

print("Text loaded successfully!")
# Out:
# Text loaded successfully!

# %% [markdown]
# ### Perform simple preprocessing tasks

# %%
# Convert the entire text to lowercase
lowercase_text = text_data.lower()
print("Text converted to lowercase:")
print(lowercase_text)
# Out:
# Text converted to lowercase:
# natural language processing (nlp) is a subfield of artificial intelligence, computer science, and computational linguistics. it is concerned with the interactions between computers and human (natural) languages, in particular how to program computers to process and analyze large amounts of natural language data. the goal is to enable computers to understand, interpret, and generate human language in a valuable way.

# %%
# Import the installed libraries
import nltk
import spacy

# Download necessary NLTK data (e.g., for tokenization)
nltk.download('punkt')
nltk.download('punkt_tab') # Added to resolve LookupError

print("NLTK and spaCy are installed and ready!")
# Out:
# NLTK and spaCy are installed and ready!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Count the number of words in the text
words = nltk.word_tokenize(text_data)
word_count = len(words)
print(f"Number of words in the text: {word_count}")
# Out:
# Number of words in the text: 72

# %%
# Import the installed libraries
import nltk
import spacy

# Download necessary NLTK data (e.g., for tokenization)
nltk.download('punkt')
nltk.download('punkt_tab') # Added to resolve LookupError

print("NLTK and spaCy are installed and ready!")
# Out:
# NLTK and spaCy are installed and ready!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Count the number of words in the text
words = nltk.word_tokenize(text_data)
word_count = len(words)
print(f"Number of words in the text: {word_count}")
# Out:
# Number of words in the text: 72

# %%
# Convert the entire text to lowercase
lowercase_text = text_data.lower()
print("Text converted to lowercase:")
print(lowercase_text)
# Out:
# Text converted to lowercase:
# natural language processing (nlp) is a subfield of artificial intelligence, computer science, and computational linguistics. it is concerned with the interactions between computers and human (natural) languages, in particular how to program computers to process and analyze large amounts of natural language data. the goal is to enable computers to understand, interpret, and generate human language in a valuable way.
